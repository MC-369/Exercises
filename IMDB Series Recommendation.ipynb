# %%
import pandas as pd 
import numpy as np

# %%
import re

# %%
df = pd.read_csv("\computer vision\datasets\IMDB_series_data.csv.xls")

# %%
df
# Out:
#                                             Poster_Link      Series_Title  \
# 0     https://m.media-amazon.com/images/M/MV5BYTRiND...   Game of Thrones
# 1     https://m.media-amazon.com/images/M/MV5BMjhiMz...      Breaking Bad
# 2     https://m.media-amazon.com/images/M/MV5BMTc5Zm...  The Walking Dead
# 3     https://m.media-amazon.com/images/M/MV5BNDVkYj...           Friends
# 4     https://m.media-amazon.com/images/M/MV5BMjEzMD...   Stranger Things
# ...                                                 ...               ...
# 1995  https://m.media-amazon.com/images/M/MV5BYTk4OG...      Shaman Kingu
# 1996  https://m.media-amazon.com/images/M/MV5BMTUyND...    Eerie, Indiana
# 1997  https://m.media-amazon.com/images/M/MV5BMTcxMD...          Gunsmoke
# 1998  https://m.media-amazon.com/images/M/MV5BYWQwNm...         The Cheat
# 1999  https://m.media-amazon.com/images/M/MV5BMjQ5Mj...    Comic Book Men
#
#      Runtime_of_Series Certificate Runtime_of_Episodes  \
# 0          (2011–2019)           A              57 min
# 1          (2008–2013)          18              49 min
# 2             (2010– )         18+              44 min
# 3          (1994–2004)         13+              22 min
# 4             (2016– )          15              51 min
# ...                ...         ...                 ...
# 1995       (2001–2005)         NaN              23 min
# 1996       (1991–1992)         NaN              30 min
# 1997       (1955–1975)         NaN              60 min
# 1998          (2017– )         NaN              20 min
# 1999       (2012–2018)         NaN              22 min
#
#                              Genre  IMDB_Rating  \
# 0         Action, Adventure, Drama          9.3
# 1           Crime, Drama, Thriller          9.5
# 2          Drama, Horror, Thriller          8.2
# 3                  Comedy, Romance          8.9
# 4           Drama, Fantasy, Horror          8.7
# ...                            ...          ...
# 1995  Animation, Action, Adventure          8.1
# 1996      Adventure, Comedy, Drama          8.2
# 1997                       Western          7.9
# 1998         Action, Drama, Sci-Fi          8.8
# 1999            Comedy, Reality-TV          7.7
#
#                                                Overview               Star1  \
# 0     Nine noble families fight for control over the...       Emilia Clarke
# 1     A high school chemistry teacher diagnosed with...      Bryan Cranston
# 2     Sheriff Deputy Rick Grimes wakes up from a com...      Andrew Lincoln
# 3     Follows the personal and professional lives of...    Jennifer Aniston
# 4     When a young boy disappears, his mother, a pol...  Millie Bobby Brown
# ...                                                 ...                 ...
# 1995  SHAMAN KING follows the adventures of a 13-yea...        Oliver Wyman
# 1996  Teenage weirdness investigator Marshall Teller...           Omri Katz
# 1997  Marshal Matt Dillon keeps the peace in rough a...        James Arness
# 1998  Felix is a software developer who works for th...        Taha Ulukaya
# 1999  An unscripted series set in Smith's iconic com...         Kevin Smith
#
#                  Star2                  Star3               Star4  No_of_Votes
# 0       Peter Dinklage          Kit Harington         Lena Headey      1773458
# 1           Aaron Paul              Anna Gunn        Betsy Brandt      1468887
# 2        Norman Reedus        Melissa McBride        Danai Gurira       854698
# 3        Courteney Cox            Lisa Kudrow        Matt LeBlanc       829816
# 4        Finn Wolfhard           Winona Ryder       David Harbour       824966
# ...                ...                    ...                 ...          ...
# 1995   Andrew Rannells  Michael Sinterniklaas  Megumi Hayashibara         5131
# 1996  Justin Shenkarow    Mary-Margaret Humes      Francis Guinan         5128
# 1997     Milburn Stone           Amanda Blake          Ken Curtis         5115
# 1998       Taner Sahin          Andac Ulukaya     Neslihan Ulusoy         5111
# 1999   Walter Flanagan            Mike Zapcic       Bryan Johnson         5109
#
# [2000 rows x 13 columns]

# %%
df["Runtime_of_Series"].unique()
# Out:
# array(['(2011–2019)', '(2008–2013)', '(2010– )', '(1994–2004)',
#        '(2016– )', '(2010–2017)', '(2007–2019)', '(2006–2021)',
#        '(2005–2014)', '(2014– )', '(2004–2010)', '(2005–2017)',
#        '(2013–2018)', '(2011– )', '(2013–2020)', '(2005–2013)',
#        '(2004–2012)', '(2012–2020)', '(2005–2020)', '(2013– )',
#        '(1989– )', '(2015–2018)', '(2015–2017)', '(2009–2020)',
#        '(2015–2019)', '(1997– )', '(2015–2021)', '(2011–2020)',
#        '(1999– )', '(1999–2007)', '(2019– )', '(2017– )', '(2002–2008)',
#        '(2017–2020)', '(2009–2017)', '(2013–2019)', '(2003–2019)',
#        '(2008–2014)', '(1989–1998)', '(2005– )', '(2005–2008)',
#        '(2002–2003)', '(2003–2015)', '(2006–2007)', '(2001–2010)',
#        '(II) (2006–2010)', '(2013–2015)', '(2013–2022)', '(2010–2013)',
#        '(2009–2015)', '(2017–2019)', '(2014–2020)', '(1999–2013)',
#        '(2014–2019)', '(2011–2018)', '(2007–2015)', '(2011–2021)',
#        '(1993–2018)', '(1990–1991)', '(2010–2014)', '(2007–2014)',
#        '(2008– )', '(2010–2015)', '(2011–2016)', '(2004–2011)',
#        '(2005–2007)', '(2007–2012)', '(1998–2006)', '(2004–2009)',
#        '(2018– )', '(2018–2020)', '(2009–2016)', '(2009– )',
#        '(2006–2013)', '(1997–2003)', '(1999–2000)', '(2011–2017)',
#        '(2009–2012)', '(1990–1996)', '(2010–2019)', '(2001–2005)',
#        '(2003– )', '(2009–2014)', '(2000–2006)', '(2016–2018)',
#        '(2015– )', '(2001–2011)', '(2016–2020)', '(2017–2018)',
#        '(1996–2003)', '(2011–2015)', '(2014–2016)', '(2009–2011)',
#        '(2002– )', '(1998–2004)', '(2012–2014)', '(2000– )',
#        '(1990–1995)', '(2005–2012)', '(1987–1994)', '(2016–2019)',
#        '(2013–2017)', '(2000–2007)', '(2012–2019)', '(2001–2003)',
#        '(2011–2014)', '(1987–1997)', '(2005–2009)', '(2004–2006)',
#        '-2018', '(2009–2013)', '(2014–2017)', '(1998–1999)',
#        '(1992–1995)', '(2013–2016)', '-2020', '(2006–2014)',
#        '(1975–1979)', '(2007–2017)', '(I) (2013–2016)', '(1997–2007)',
#        '(2003–2007)', '(2008–2010)', '-2011', '(2000–2015)',
#        '(2010–2018)', '(1998–2007)', '(2018–2019)', '(2007–2013)',
#        '(2012–2016)', '(1993–2004)', '(2008–2012)', '(1966–1969)',
#        '(2015–2016)', '(2003–2012)', '(1959–1964)', '(2002–2007)',
#        '(2015–2020)', '(2007–2010)', '(1989–1996)', '(1969–1974)',
#        '(2020– )', '(2004–2019)', '(2012–2018)', '(2010–2020)',
#        '(I) (2018– )', '(2002–2009)', '(2012–2017)', '(1999–2006)',
#        '(1999–2004)', '(1996– )', '(2008–2020)', '(2003–2004)',
#        '(2017–2021)', '(1995–2001)', '(2009–2010)', '(I) (2012–2015)',
#        '(2008–2009)', '-2017', '(2006–2011)', '(2007–2009)',
#        '(2003–2006)', '(2000–2004)', '(2014–2018)', '(2016–2017)',
#        '(2006–2008)', '(2002–2012)', '(1995–2003)', '(2021– )',
#        '(1993–1999)', '(2014–2015)', '(1987–1995)', '(2003–2010)',
#        '(I) (2019– )', '(II) (2017– )', '(2006–2012)', '(1998–2020)',
#        '(1995–1996)', '(1994–2009)', '(1999–2001)', '(1972–1983)',
#        '(2010–2011)', '-1989', '(2011–2013)', '(1982–1993)',
#        '(1986–1989)', '(2013–2014)', '(1996–2001)', '(1981–2003)',
#        '(2001–2017)', '(1997–2010)', '(2001–2006)', '(2011–2012)',
#        '(2009–2018)', '(I) (2009–2015)', '(2004–2013)', '-1986',
#        '(1975– )', '(2005–2010)', '(2004–2008)', '(2003–2005)',
#        '(2004–2007)', '(2012–2013)', '(I) (2013–2014)', '(2001–2004)',
#        '-1987', '(2004–2005)', '(1991–1999)', '(2006–2010)',
#        '(I) (2014–2020)', '(1988–2018)', '(1993–2000)', '(2012– )',
#        '-2012', '(1989–2013)', '(1999–2002)', '(1992–1997)',
#        '(2001–2018)', '(1998–2005)', '-2014', '(1995–1998)',
#        '(1998–2003)', '(1982–1983)', '(1985–1992)', '(1963–1989)',
#        '(1983–1987)', '(1988–1993)', '(2001–2009)', '(1999–2003)',
#        '(1999–2008)', '(1960–1966)', '(1997–2004)', '(1988– )',
#        '(I) (2007–2009)', '(1989–1992)', '(1990–2006)', '(1990–2010)',
#        '(1986–1990)', '(1984–1992)', '(1990–2000)', '(1960–1975)',
#        '(2000–2002)', '(1987–1996)', '(1996–2004)', '(1997–2002)',
#        '(1982–1986)', '(1969–1970)', '(2010–2012)', '(2010–2016)',
#        '(1987–1990)', '(1997–1998)', '(2013–2021)', '(1971–2003)',
#        '(1993–1998)', '(2006–2009)', '-2019', '(1993–2011)',
#        '(1995–1999)', '(1994–1998)', '(2006– )', '(1996–2002)',
#        '(1989–1993)', '(2003–2008)', '(2005–2011)', '-2009',
#        '(1989–2001)', '(1978–2002)', '(I) (2004–2009)', '(1996–2007)',
#        '(2002–2005)', '(1982–1992)', '(2003–2018)', '(2007–2008)',
#        '(2007–2011)', '(1984–1989)', '(1997–2001)', '-2016',
#        '(1988–1999)', '(1976–1981)', '(1980–1988)', '-2015',
#        '(1951–1957)', '(2006–2020)', '(1993–1997)', '(1992–2019)',
#        '(I) (2012–2013)', '(II) (2020– )', '(2019–2020)', '(1991–1996)',
#        '(2001–2007)', '(2009–2019)', '(1984–1987)', '(I) (2017– )',
#        '(1993–1996)', '(1984–1985)', '(2012–2015)', '-1998',
#        '(2008–2011)', '(1994–1995)', '(1966–1968)', '(1983–1986)',
#        '(2004–2018)', '(2000–2005)', '(1984–1996)', '(1962–1963)',
#        '(I) (2000–2006)', '(1997–1999)', '(1974–1983)', '(1985–1989)',
#        '(1992–2012)', '(2002–2006)', '(1991–1994)', '(1996–1999)',
#        '(1964–1972)', '(II) (2020–2021)', '(1988–1990)', '(1993–2009)',
#        '(1991–1992)', '(1995–2000)', '(1995–2005)', '(1974–1984)',
#        '(1983–1985)', '(1995–2004)', '(1982–1989)', '(1969–2011)',
#        '(1981–1989)', '-1982', '(2008–2015)', '(1998–2001)',
#        '(1985–1986)', '(2008–2021)', '(1993–2001)', '(I) (2019)',
#        '(2014–2021)', '(2004–2017)', '(1955–1962)', '(1996–2000)',
#        '(1964–1966)', '(2002–2011)', '(1994–1996)', '(1987–1988)',
#        '(1971–1979)', '(1992–1998)', '(2004– )', '(1978–1979)', '-2007',
#        '(2000–2003)', '(2001– )', '(1982–1984)', '(1965–1970)',
#        '(2020–2021)', '(1964–1967)', '(2008–2016)', '(1993–2015)',
#        '(1991–1998)', '(2002–2015)', '(1980–1984)', '-2006',
#        '(1967–1968)', '(1976–1984)', '(1960–1968)', '(1978–1991)',
#        '(2007–2020)', '(1969– )', '-2004', '(1994–2020)', '(2000–2001)',
#        '(1977–1982)', '(2005–2006)', '-2010', '(1993–2005)',
#        '(1995–1997)', '(1991–1995)', '(1990–1993)', '(I) (2016)',
#        '(1978–1983)', '(1979–1985)', '(2001–2015)', '(II) (2015–2018)',
#        '(1995–2002)', '(1994–1999)', '(1992–1999)', '(1987–1991)',
#        '(1990–1997)', '(2006–2015)', '(1986–1988)', '(1998–2002)',
#        '(1994–1997)', '(2005–2015)', '(2007– )', '(2002–2019)', '-1981',
#        '(1987–2000)', '(1999–2017)', '(1960–1962)', '(1984–1986)',
#        '(1988–1995)', '(1992–2014)', '(I) (1996–1999)', '(1978–1982)',
#        '(1995–2016)', '(2007–2016)', '(1986–1987)', '(1985–1991)',
#        '(II) (2000– )', '(1978–1986)', '(II) (2007– )', '(1974–1978)',
#        '(1968–1978)', '(1994–2000)', '(I) (2005– )', '(1961–1988)',
#        '(1966–1973)', '(1977–1987)', '(1999–2005)', '(1992–1996)',
#        '(2001–2014)', '(2003–2009)', '(1961–1966)', '-2021',
#        '(2000–2011)', '(1965–1971)', '(1986–1991)', '-2008',
#        '(1986–1993)', '(1988–2021)', '(2001–2002)', '(I) (2006– )',
#        '(1993– )', '(1977–1983)', '(1962–1971)', '(II) (2012– )',
#        '(1959–1973)', '(1975–1977)', '(1972–1977)', '(1993–1994)',
#        '(1977–1986)', '(1979–1981)', '(1975–1985)', '(1992–1993)',
#        '(II) (2010– )', '(1985– )', '(1968–2001)', '(1994–2001)', '-2013',
#        '(I) (2016–2017)', '(1982–1987)', '(1981–1987)', '(1998–2000)',
#        '(1963–1965)', '(1972–1985)', '(1987– )', '(1970–1977)',
#        '(2005–2018)', '(1974–1980)', '(1961–1962)', '(1994–2019)',
#        '(1977–1984)', '(1961–1969)', '(I) (2016–2018)', '(1957–1963)',
#        '(1973–1978)', '(1965–1968)', '(1989–1991)', '(1997–2016)',
#        '(1998–2012)', '(1986–1995)', '(1976–1983)', '(1992–2010)',
#        '(1981–1986)', '(1979–1984)', '(I) (2001–2012)', '(1994–2003)',
#        '(1976–1978)', '(I) (2020)', '(1992–2011)', '(1984– )', '(1965– )',
#        '(2002–2014)', '(1979–1988)', '(1968–1970)', '(1973–1975)',
#        '(1989–1997)', '(1974–1979)', '(1977–1981)', '(1957– )',
#        '(1983–1995)', '(2004–2020)', '(1980–2006)', '(1982–1990)',
#        '(1972–1981)', '(1968–1980)', '(1987–1993)', '(I) (2017)',
#        '(1990–2001)', '(2000–2009)', '(1999–2010)', '(1968–1977)',
#        '(1983–1988)', '(1973– )', '(2004–2014)', '(2000–2019)',
#        '(1974–1977)', '(1989–2020)', '(1984–1990)', '(I) (2018)',
#        '(1970–1975)', '(1988–1998)', '(1972–1975)', '-2001',
#        '(1996–2015)', '(1957–1966)', '(1985–1987)', '(1955–1975)'],
#       dtype=object)

# %%
df.describe()
# Out:
#        IMDB_Rating   No_of_Votes
# count  2000.000000  2.000000e+03
# mean      7.591300  3.770391e+04
# std       0.898731  8.843231e+04
# min       1.000000  5.109000e+03
# 25%       7.200000  7.745500e+03
# 50%       7.700000  1.316100e+04
# 75%       8.200000  3.132200e+04
# max       9.700000  1.773458e+06

# %%
df.isnull().sum()
# Out:
# Poster_Link               0
# Series_Title              0
# Runtime_of_Series         0
# Certificate            1297
# Runtime_of_Episodes      43
# Genre                     0
# IMDB_Rating               0
# Overview                  0
# Star1                     0
# Star2                     0
# Star3                     1
# Star4                     5
# No_of_Votes               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Runtime_of_Series', 'Certificate',
#        'Runtime_of_Episodes', 'Genre', 'IMDB_Rating', 'Overview', 'Star1',
#        'Star2', 'Star3', 'Star4', 'No_of_Votes'],
#       dtype='object')

# %%
df2 = df[["Series_Title","Runtime_of_Series","Runtime_of_Episodes","Certificate","Genre","IMDB_Rating","No_of_Votes"]]

# %%
df2
# Out:
#           Series_Title Runtime_of_Series Runtime_of_Episodes Certificate  \
# 0      Game of Thrones       (2011–2019)              57 min           A
# 1         Breaking Bad       (2008–2013)              49 min          18
# 2     The Walking Dead          (2010– )              44 min         18+
# 3              Friends       (1994–2004)              22 min         13+
# 4      Stranger Things          (2016– )              51 min          15
# ...                ...               ...                 ...         ...
# 1995      Shaman Kingu       (2001–2005)              23 min         NaN
# 1996    Eerie, Indiana       (1991–1992)              30 min         NaN
# 1997          Gunsmoke       (1955–1975)              60 min         NaN
# 1998         The Cheat          (2017– )              20 min         NaN
# 1999    Comic Book Men       (2012–2018)              22 min         NaN
#
#                              Genre  IMDB_Rating  No_of_Votes
# 0         Action, Adventure, Drama          9.3      1773458
# 1           Crime, Drama, Thriller          9.5      1468887
# 2          Drama, Horror, Thriller          8.2       854698
# 3                  Comedy, Romance          8.9       829816
# 4           Drama, Fantasy, Horror          8.7       824966
# ...                            ...          ...          ...
# 1995  Animation, Action, Adventure          8.1         5131
# 1996      Adventure, Comedy, Drama          8.2         5128
# 1997                       Western          7.9         5115
# 1998         Action, Drama, Sci-Fi          8.8         5111
# 1999            Comedy, Reality-TV          7.7         5109
#
# [2000 rows x 7 columns]

# %%
df2.dtypes
# Out:
# Series_Title            object
# Runtime_of_Series       object
# Runtime_of_Episodes     object
# Certificate             object
# Genre                   object
# IMDB_Rating            float64
# No_of_Votes              int64
# dtype: object

# %%
def newyear_range(runtime):
    #removing symbols
    runt = re.sub(r'[\(\)–\s]', '', runtime)
    #spliting to start and end year
    start_year = runt[:4]
    end_year = runt[4:]
    if end_year == '':
        end_year = 'Present'
    return f"{start_year}-{end_year}"

# %%
new_array = [newyear_range(runtime) for runtime in df2["Runtime_of_Series"]]

# %%
type(new_array)
# Out:
# list

# %%
df2["Runtime_of_Series"] = new_array
# Out:
# C:\Users\mchan\AppData\Local\Temp\ipykernel_5412\4200314564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Runtime_of_Series"] = new_array

# %%
df2
# Out:
#           Series_Title Runtime_of_Series Runtime_of_Episodes Certificate  \
# 0      Game of Thrones         2011-2019              57 min           A
# 1         Breaking Bad         2008-2013              49 min          18
# 2     The Walking Dead      2010-Present              44 min         18+
# 3              Friends         1994-2004              22 min         13+
# 4      Stranger Things      2016-Present              51 min          15
# ...                ...               ...                 ...         ...
# 1995      Shaman Kingu         2001-2005              23 min         NaN
# 1996    Eerie, Indiana         1991-1992              30 min         NaN
# 1997          Gunsmoke         1955-1975              60 min         NaN
# 1998         The Cheat      2017-Present              20 min         NaN
# 1999    Comic Book Men         2012-2018              22 min         NaN
#
#                              Genre  IMDB_Rating  No_of_Votes
# 0         Action, Adventure, Drama          9.3      1773458
# 1           Crime, Drama, Thriller          9.5      1468887
# 2          Drama, Horror, Thriller          8.2       854698
# 3                  Comedy, Romance          8.9       829816
# 4           Drama, Fantasy, Horror          8.7       824966
# ...                            ...          ...          ...
# 1995  Animation, Action, Adventure          8.1         5131
# 1996      Adventure, Comedy, Drama          8.2         5128
# 1997                       Western          7.9         5115
# 1998         Action, Drama, Sci-Fi          8.8         5111
# 1999            Comedy, Reality-TV          7.7         5109
#
# [2000 rows x 7 columns]

# %%
df2['Genre'] = df2['Genre'].fillna('[]')
# Out:
# C:\Users\mchan\AppData\Local\Temp\ipykernel_5412\1284317396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Genre'] = df2['Genre'].fillna('[]')

# %%
df2
# Out:
#           Series_Title Runtime_of_Series Runtime_of_Episodes Certificate  \
# 0      Game of Thrones         2011-2019              57 min           A
# 1         Breaking Bad         2008-2013              49 min          18
# 2     The Walking Dead      2010-Present              44 min         18+
# 3              Friends         1994-2004              22 min         13+
# 4      Stranger Things      2016-Present              51 min          15
# ...                ...               ...                 ...         ...
# 1995      Shaman Kingu         2001-2005              23 min         NaN
# 1996    Eerie, Indiana         1991-1992              30 min         NaN
# 1997          Gunsmoke         1955-1975              60 min         NaN
# 1998         The Cheat      2017-Present              20 min         NaN
# 1999    Comic Book Men         2012-2018              22 min         NaN
#
#                              Genre  IMDB_Rating  No_of_Votes
# 0         Action, Adventure, Drama          9.3      1773458
# 1           Crime, Drama, Thriller          9.5      1468887
# 2          Drama, Horror, Thriller          8.2       854698
# 3                  Comedy, Romance          8.9       829816
# 4           Drama, Fantasy, Horror          8.7       824966
# ...                            ...          ...          ...
# 1995  Animation, Action, Adventure          8.1         5131
# 1996      Adventure, Comedy, Drama          8.2         5128
# 1997                       Western          7.9         5115
# 1998         Action, Drama, Sci-Fi          8.8         5111
# 1999            Comedy, Reality-TV          7.7         5109
#
# [2000 rows x 7 columns]

# %%
s = df2.apply(lambda x: pd.Series(x['Genre']),axis=1).stack().reset_index(level=1,drop=True)

# %%
s.name = "Genre"

# %%
split_genre = s.str.split(', ').explode()

split_genre = split_genre.reset_index(drop=True)

# %%
df2["Genre"] = split_genre
# Out:
# C:\Users\mchan\AppData\Local\Temp\ipykernel_5412\3811240901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Genre"] = split_genre

# %%
df2
# Out:
#           Series_Title Runtime_of_Series Runtime_of_Episodes Certificate  \
# 0      Game of Thrones         2011-2019              57 min           A
# 1         Breaking Bad         2008-2013              49 min          18
# 2     The Walking Dead      2010-Present              44 min         18+
# 3              Friends         1994-2004              22 min         13+
# 4      Stranger Things      2016-Present              51 min          15
# ...                ...               ...                 ...         ...
# 1995      Shaman Kingu         2001-2005              23 min         NaN
# 1996    Eerie, Indiana         1991-1992              30 min         NaN
# 1997          Gunsmoke         1955-1975              60 min         NaN
# 1998         The Cheat      2017-Present              20 min         NaN
# 1999    Comic Book Men         2012-2018              22 min         NaN
#
#           Genre  IMDB_Rating  No_of_Votes
# 0        Action          9.3      1773458
# 1     Adventure          9.5      1468887
# 2         Drama          8.2       854698
# 3         Crime          8.9       829816
# 4         Drama          8.7       824966
# ...         ...          ...          ...
# 1995      Drama          8.1         5131
# 1996    Mystery          8.2         5128
# 1997  Animation          7.9         5115
# 1998     Action          8.8         5111
# 1999  Adventure          7.7         5109
#
# [2000 rows x 7 columns]

# %%
df2["Genre"].fillna(df2["Genre"].mode()[0],inplace=True)
# Out:
# C:\Users\mchan\AppData\Local\Temp\ipykernel_5412\2914621542.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Genre"].fillna(df2["Genre"].mode()[0],inplace=True)

# %%
df2["Certificate"].fillna(df2["Certificate"].mode()[0],inplace=True)
# Out:
# C:\Users\mchan\AppData\Local\Temp\ipykernel_5412\4231345345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Certificate"].fillna(df2["Certificate"].mode()[0],inplace=True)

# %%
df2["Release_year"] = df2["Runtime_of_Series"].apply(lambda x: str(x).split('-')[0] )
# Out:
# C:\Users\mchan\AppData\Local\Temp\ipykernel_5412\2970625972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Release_year"] = df2["Runtime_of_Series"].apply(lambda x: str(x).split('-')[0] )

# %%
df2
# Out:
#           Series_Title Runtime_of_Series Runtime_of_Episodes Certificate  \
# 0      Game of Thrones         2011-2019              57 min           A
# 1         Breaking Bad         2008-2013              49 min          18
# 2     The Walking Dead      2010-Present              44 min         18+
# 3              Friends         1994-2004              22 min         13+
# 4      Stranger Things      2016-Present              51 min          15
# ...                ...               ...                 ...         ...
# 1995      Shaman Kingu         2001-2005              23 min          18
# 1996    Eerie, Indiana         1991-1992              30 min          18
# 1997          Gunsmoke         1955-1975              60 min          18
# 1998         The Cheat      2017-Present              20 min          18
# 1999    Comic Book Men         2012-2018              22 min          18
#
#           Genre  IMDB_Rating  No_of_Votes Release_year
# 0        Action          9.3      1773458         2011
# 1     Adventure          9.5      1468887         2008
# 2         Drama          8.2       854698         2010
# 3         Crime          8.9       829816         1994
# 4         Drama          8.7       824966         2016
# ...         ...          ...          ...          ...
# 1995      Drama          8.1         5131         2001
# 1996    Mystery          8.2         5128         1991
# 1997  Animation          7.9         5115         1955
# 1998     Action          8.8         5111         2017
# 1999  Adventure          7.7         5109         2012
#
# [2000 rows x 8 columns]

# %%
df2["Release_year"].unique()
# Out:
# array(['2011', '2008', '2010', '1994', '2016', '2007', '2006', '2005',
#        '2014', '2004', '2013', '2012', '1989', '2015', '2009', '1997',
#        '1999', '2019', '2017', '2002', '2003', '2001', 'II20', '1993',
#        '1990', '1998', '2018', '2000', '1996', '1987', '', '1992', '1975',
#        'I201', '1966', '1959', '1969', '2020', '1995', '2021', '1972',
#        '1982', '1986', '1981', 'I200', '1991', '1988', '1985', '1963',
#        '1983', '1960', '1984', '1971', '1978', '1976', '1980', '1951',
#        '1962', '1974', '1964', '1955', '1965', '1967', '1977', '1979',
#        'I199', '1968', '1961', '1970', '1957', '1973', 'I202'],
#       dtype=object)

# %%
df2["Certificate"].value_counts()
# Out:
# Certificate
# 18           1528
# 16            133
# 16+            49
# 15+            45
# A              42
# 13             42
# 18+            41
# U              29
# 12+            18
# 7              16
# UA             14
# PG             13
# 13+             9
# All             6
# Not Rated       6
# 15              4
# 7+              3
# R               2
# Name: count, dtype: int64

# %%
def build_chart(df2,percentile=0.08):
    print("Preferred Genre: ")
    genre = input().capitalize()
    print("Preferred Certificate: ")
    certificate = str(input())
    print("Release Year)") 
    year = str(input())
    movies=df2.copy()
    movies=movies[(movies["Genre"]==genre) & (movies["Certificate"]==certificate) & (movies["Release_year"]==year)]
    C = movies["IMDB_Rating"].mean()
    m = movies["No_of_Votes"].quantile(percentile)
    q_movies = movies.copy().loc[movies['No_of_Votes']>=m]
    q_movies['score'] = q_movies.apply(lambda x: (x['No_of_Votes']/(x['No_of_Votes']+m)* x['IMDB_Rating']) + (m/(m+x['No_of_Votes'])*C),axis=1)
    q_movies = q_movies.sort_values(by='score',ascending=False)
    return q_movies

# %%
build_chart(df2).head()
# Out:
# Preferred Genre:
