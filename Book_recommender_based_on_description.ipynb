# %%
import numpy as np
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
data = pd.read_csv('books.csv')

# %%
data
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
data.isnull().sum()
# Out:
# isbn13               0
# isbn10               0
# title                0
# subtitle          4429
# authors             72
# categories          99
# thumbnail          329
# description        262
# published_year       6
# average_rating      43
# num_pages           43
# ratings_count       43
# dtype: int64

# %%
data.columns
# Out:
# Index(['isbn13', 'isbn10', 'title', 'subtitle', 'authors', 'categories',
#        'thumbnail', 'description', 'published_year', 'average_rating',
#        'num_pages', 'ratings_count'],
#       dtype='object')

# %%
data_new = data.drop(['isbn13', 'isbn10', 'subtitle', 'thumbnail', 'published_year', 'average_rating',
       'num_pages', 'ratings_count'],axis=1)

# %%
data_new
# Out:
#                           title                                       authors  \
# 0                        Gilead                            Marilynne Robinson
# 1                  Spider's Web               Charles Osborne;Agatha Christie
# 2                  The One Tree                          Stephen R. Donaldson
# 3                Rage of angels                                Sidney Sheldon
# 4                The Four Loves                           Clive Staples Lewis
# ...                         ...                                           ...
# 6805                  I Am that  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6806       Secrets Of The Heart                                 Khalil Gibran
# 6807             Fahrenheit 451                                  Ray Bradbury
# 6808   The Berlin Phenomenology                 Georg Wilhelm Friedrich Hegel
# 6809  'I'm Telling You Stories'                        Helena Grice;Tim Woods
#
# ...

# %%
data_new.isnull().sum()
# Out:
# title            0
# authors         72
# categories      99
# description    262
# dtype: int64

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
data_new['description'] = data_new['description'].fillna('')
data_new['authors'] = data_new['authors'].fillna('')
data_new['categories'] = data_new['categories'].fillna('')

# %%
data_new.isnull().sum()
# Out:
# title          0
# authors        0
# categories     0
# description    0
# dtype: int64

# %%
data_new
# Out:
#                           title                                       authors  \
# 0                        Gilead                            Marilynne Robinson
# 1                  Spider's Web               Charles Osborne;Agatha Christie
# 2                  The One Tree                          Stephen R. Donaldson
# 3                Rage of angels                                Sidney Sheldon
# 4                The Four Loves                           Clive Staples Lewis
# ...                         ...                                           ...
# 6805                  I Am that  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6806       Secrets Of The Heart                                 Khalil Gibran
# 6807             Fahrenheit 451                                  Ray Bradbury
# 6808   The Berlin Phenomenology                 Georg Wilhelm Friedrich Hegel
# 6809  'I'm Telling You Stories'                        Helena Grice;Tim Woods
#
# ...

# %%
data_new.shape
# Out:
# (6810, 4)

# %%
tfidf_matrix =tfidf.fit_transform(data_new['description'])

# %%
tfidf_matrix.shape
# Out:
# (6810, 30338)

# %%
data_new.shape
# Out:
# (6810, 4)

# %%
cosine_sim = linear_kernel(tfidf_matrix,tfidf_matrix)

# %%
cosine_sim
# Out:
# array([[1.        , 0.00195947, 0.        , ..., 0.        , 0.00566757,
#         0.        ],
#        [0.00195947, 1.        , 0.01590235, ..., 0.        , 0.00348256,
#         0.02986498],
#        [0.        , 0.01590235, 1.        , ..., 0.        , 0.00935964,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.00566757, 0.00348256, 0.00935964, ..., 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.02986498, 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %%
indices = pd.Series(data_new.index,index=data_new['title']).drop_duplicates()
indices
# Out:
# title
# Gilead                          0
# Spider's Web                    1
# The One Tree                    2
# Rage of angels                  3
# The Four Loves                  4
#                              ...
# I Am that                    6805
# Secrets Of The Heart         6806
# Fahrenheit 451               6807
# The Berlin Phenomenology     6808
# 'I'm Telling You Stories'    6809
# Length: 6810, dtype: int64

# %%
def book_recommender(title,cosine_sim=cosine_sim,df=data_new,indices=indices):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores  = sorted(sim_scores,key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    book_indices = [i[0] for i in sim_scores]
    return df['title'].iloc[book_indices]

# %%
book_recommender('Gilead')
# Out:
# 2311           The Handmaid's Tale
# 918     Go Tell it on the Mountain
# 2248         Children of the Alley
# 3360           The Last Eyewitness
# 4091                    John Adams
# 330      The Chaneysville Incident
# 6435             A Time to Embrace
# 954                    Vanity Fair
# 2051               Martin and John
# 744      The Deep End of the Ocean
# Name: title, dtype: object
